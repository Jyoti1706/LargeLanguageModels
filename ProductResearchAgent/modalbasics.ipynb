# %% [markdown]
# ## Modal
#
# ### Setting up the modal tokens
#
# The first time you run this, please uncomment the next line and execute it.
# This is the same as running `modal setup` from the command line. It connects with Modal and installs your tokens.
#
# A student on Windows mentioned that on Windows, you might also need to run this command from a command prompt afterwards:
# `modal token new`
# (Thank you Ed B. for that!)
#
# And I've also heard that in some situations, you might need to restart the Kernel of this jupyter notebook after running this. (Kernel menu >> Restart Kernel and Clear Outputs of All Cells).
#
# #!modal setup

# %%
import modal

# %%
#!modal setup

# %%
from hello import app, hello

# %%
#!pip install requests

# %%
with app.run(show_progress=False):
    reply=hello.local()
reply
# Out:
# c:\Users\jyoti\Documents\Projects\AgenticAI\.conda\Lib\contextlib.py:210: DeprecationError: 2024-11-20: `show_progress=False` is deprecated (and has no effect)
#   return await anext(self.gen)
# 'Hello from Bengaluru, Karnataka, IN!!'

# %%
with app.run():
    reply=hello.remote()
reply
# Out:
# 'Hello from Ashburn, Virginia, US!!'

# %% [markdown]
# ### Working with HF models

# %%
from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Life is a mystery, everyone must stand alone, I hear")
result
# Out:
# ✓ Initialized. View run at https://modal.com/apps/jyotikrisharma101/main/ap-Ruh2DFN8htCy1KiAWa2QJY
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\llama.py
# ├── 🔨 Created mount PythonPackage:hello
# └── 🔨 Created function generate.
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading shards:  25%|██▌       | 1/4 [07:58<23:55, 478.35s/it]
# Downloading shards:  50%|█████     | 2/4 [15:58<15:58, 479.48s/it]
# Downloading shards:  75%|███████▌  | 3/4 [23:51<07:56, 476.36s/it]
# Downloading shards: 100%|██████████| 4/4 [25:43<00:00, 332.62s/it]Downloading shards: 100%|██████████| 4/4 [25:43<00:00, 385.88s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:06<00:20,  6.75s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:13<00:13,  6.74s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:19<00:06,  6.29s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:20<00:00,  4.29s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:20<00:00,  5.12s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at https://modal.com/apps/jyotikrisharma101/main/ap-Ruh2DFN8htCy1KiAWa2QJY
# '<|begin_of_text|>Life is a mystery, everyone must stand alone, I hear you call my name,'

# %%
import modal
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
# Out:
# ✓ Initialized. View run at https://modal.com/apps/jyotikrisharma101/main/ap-KU7mAQDUiunnMPxyGqlTKQ
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Building image im-GmVNj7ivbolcI5oH0Al7Tq
# => Step 0: FROM base
# => Step 1: RUN python -m pip install accelerate bitsandbytes peft torch transformers
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Collecting peft
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl.metadata (13 kB)
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.48.0-py3-none-any.whl.metadata (44 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.1-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.12/site-packages (from bitsandbytes) (4.12.2)
# Collecting tqdm (from peft)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting setuptools (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/setuptools/setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl (336 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 521.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl (374 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl (906.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 457.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 557.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 506.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 534.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 804.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 508.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 502.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 507.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 515.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 525.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 509.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 519.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 542.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.6 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 481.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.48.0-py3-none-any.whl (9.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 553.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.1-py3-none-any.whl (450 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 486.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl (65 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 285.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (796 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 453.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 617.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 648.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/setuptools/setuptools-75.8.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 785.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (145 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 972.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: mpmath, urllib3, tqdm, sympy, setuptools, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, charset-normalizer, triton, requests, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# Successfully installed MarkupSafe-3.0.2 accelerate-1.2.1 bitsandbytes-0.45.0 charset-normalizer-3.4.1 filelock-3.16.1 fsspec-2024.12.0 huggingface-hub-0.27.1 jinja2-3.1.5 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 packaging-24.2 peft-0.14.0 psutil-6.1.1 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.5.2 setuptools-75.8.0 sympy-1.13.1 tokenizers-0.21.0 torch-2.5.1 tqdm-4.67.1 transformers-4.48.0 triton-3.1.0 urllib3-2.3.0
# Saving image...
# Image saved, took 2.79s
# Built image im-GmVNj7ivbolcI5oH0Al7Tq in 72.69s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pricer_ephemeral.py
# ├── 🔨 Created mount PythonPackage:hello
# ├── 🔨 Created mount PythonPackage:llama
# └── 🔨 Created function price.
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading shards:  25%|██▌       | 1/4 [01:58<05:54, 118.32s/it]
# Downloading shards:  50%|█████     | 2/4 [03:56<03:56, 118.46s/it]
# Downloading shards:  75%|███████▌  | 3/4 [05:53<01:57, 117.79s/it]
# Downloading shards: 100%|██████████| 4/4 [06:21<00:00, 82.28s/it] Downloading shards: 100%|██████████| 4/4 [06:21<00:00, 95.43s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:06<00:20,  6.78s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:13<00:13,  6.68s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:20<00:06,  6.69s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:21<00:00,  4.68s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:21<00:00,  5.43s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# Runner terminated.
# ✓ App completed. View run at https://modal.com/apps/jyotikrisharma101/main/ap-KU7mAQDUiunnMPxyGqlTKQ
# 133.0

# %%
# !modal deploy pricer_service
# Out:
# - Creating objects...
# | Creating objects...
# / Creating objects...
# └── - Creating mount
#     c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
#     icer_service.py: Uploaded 0/1 files
# | Creating objects...
# └── | Creating mount
#     c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
#     icer_service.py: Uploaded 0/1 files
# / Creating objects...
# └── / Creating mount
#     c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
#     icer_service.py: Finalizing index of 1 files
# \ Creating objects...
# └── | Creating mount
#     c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
#     icer_service.py: Finalizing index of 1 files
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service.py
# └── - Creating function price...
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service.py
# └── | Creating function price...
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service.py
# └── 🔨 Created function price.
#
# ✓ Created objects.
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service.py
# └── 🔨 Created function price.
# ✓ App deployed in 3.512s! 🎉
#
# View Deployment:
# https://modal.com/apps/jyotikrisharma101/main/deployed/pricer-service

# %%
pricer = modal.Function.lookup("pricer-service", "price")

# %%
pricer.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
# Out:
# 133.0

# %%
# !modal deploy pricer_service2
# Out:
# - Creating objects...
# | Creating objects...
# / Creating objects...
# | Creating objects...
# └── - Creating mount
#     c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
#     icer_service2.py: Uploaded 0/1 files
# - Creating objects...
# └── | Creating mount
#     c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
#     icer_service2.py: Uploaded 0/1 files
# | Creating objects...
# └── - Creating mount
#     c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
#     icer_service2.py: Finalizing index of 1 files
# - Creating objects...
# └── | Creating mount
#     c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
#     icer_service2.py: Finalizing index of 1 files
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── - Creating function Pricer.download_model_to_folder...
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── | Creating function Pricer.download_model_to_folder...
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── - Creating function Pricer.download_model_to_folder...
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# Building image im-sCxbh0tBZ5E7acpl60PFv6
# / Creating objects...
# ├── 🔨 Created mount c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\Produc
# └── 🔨 Created function Pricer.download_model_to_folder.
#
# => Step 0: running function 'Pricer.download_model_to_folder'
# / Creating objects...
# ├── 🔨 Created mount c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\Produc
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
#
# - Creating objects...
# ├── 🔨 Created mount c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\Produc
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# \ Creating objects...
# ├── 🔨 Created mount c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\Produc
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# Fetching 17 files:  12%|█▏        | 2/17 [00:00<00:01,  9.02it/s]| Creating objects...
# ├── 🔨 Created mount c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\Produc
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ...
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\pr
# │   icer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.

# %%
Pricer = modal.Cls.lookup("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.local("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 Pricer = modal.Cls.lookup("pricer-service2", "Pricer")
#       2 pricer = Pricer()
#       3 reply = pricer.price.local("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
#
# File c:\Users\jyoti\Documents\Projects\AgenticAI\.conda\Lib\site-packages\synchronicity\combined_types.py:29, in FunctionWithAio.__call__(self, *args, **kwargs)
#      27 except UserCodeException as uc_exc:
#      28     uc_exc.exc.__suppress_context__ = True
# ---> 29     raise uc_exc.exc
#
# File c:\Users\jyoti\Documents\Projects\AgenticAI\.conda\Lib\site-packages\modal\cls.py:671, in _Cls.lookup(app_name, name, namespace, client, environment_name, workspace)
#     669     client = await _Client.from_env()
#     670 resolver = Resolver(client=client)
# --> 671 await resolver.load(obj)
#     672 return obj
#
# File c:\Users\jyoti\Documents\Projects\AgenticAI\.conda\Lib\site-packages\modal\_resolver.py:155, in Resolver.load(self, obj, existing_object_id)
#     152         self._deduplication_cache[deduplication_key] = cached_future
#     154 # TODO(elias): print original exception/trace rather than the Resolver-internal trace
# --> 155 return await cached_future
#
# File c:\Users\jyoti\Documents\Projects\AgenticAI\.conda\Lib\site-packages\modal\_resolver.py:128, in Resolver.load.<locals>.loader()
#     126 # Load the object itself
#     127 try:
# --> 128     await obj._load(obj, self, existing_object_id)
#     129 except GRPCError as exc:
#     130     if exc.status == Status.NOT_FOUND:
#
# File c:\Users\jyoti\Documents\Projects\AgenticAI\.conda\Lib\site-packages\modal\cls.py:556, in _Cls.from_name.<locals>._load_remote(obj, resolver, existing_object_id)
#     554 except GRPCError as exc:
#     555     if exc.status == Status.NOT_FOUND:
# --> 556         raise NotFoundError(exc.message)
#     557     elif exc.status == Status.FAILED_PRECONDITION:
#     558         raise InvalidError(exc.message)
#
# NotFoundError: App not found

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 agent = SpecialistAgent()
#       2 agent.price("iPad Pro 2nd generation")
#
# File c:\Users\jyoti\Documents\GitHub\LargeLanguageModels\ProductResearchAgent\agents\specialist_agent.py:18, in SpecialistAgent.__init__(self)
#      14 """
#      15 Set up this Agent by creating an instance of the modal class
#      16 """
#      17 self.log("Specialist Agent is initializing - connecting to modal")
# ---> 18 Pricer = modal.Cls.lookup("pricer-service", "Pricer")
#      19 self.pricer = Pricer()
#      20 self.log("Specialist Agent is ready")
#
# File c:\Users\jyoti\Documents\Projects\AgenticAI\.conda\Lib\site-packages\synchronicity\combined_types.py:29, in FunctionWithAio.__call__(self, *args, **kwargs)
#      27 except UserCodeException as uc_exc:
#      28     uc_exc.exc.__suppress_context__ = True
# ---> 29     raise uc_exc.exc
#
# File c:\Users\jyoti\Documents\Projects\AgenticAI\.conda\Lib\site-packages\modal\cls.py:671, in _Cls.lookup(app_name, name, namespace, client, environment_name, workspace)
#     669     client = await _Client.from_env()
#     670 resolver = Resolver(client=client)
# --> 671 await resolver.load(obj)
#     672 return obj
#
# File c:\Users\jyoti\Documents\Projects\AgenticAI\.conda\Lib\site-packages\modal\_resolver.py:155, in Resolver.load(self, obj, existing_object_id)
#     152         self._deduplication_cache[deduplication_key] = cached_future
#     154 # TODO(elias): print original exception/trace rather than the Resolver-internal trace
# --> 155 return await cached_future
#
# File c:\Users\jyoti\Documents\Projects\AgenticAI\.conda\Lib\site-packages\modal\_resolver.py:128, in Resolver.load.<locals>.loader()
#     126 # Load the object itself
#     127 try:
# --> 128     await obj._load(obj, self, existing_object_id)
#     129 except GRPCError as exc:
#     130     if exc.status == Status.NOT_FOUND:
#
# File c:\Users\jyoti\Documents\Projects\AgenticAI\.conda\Lib\site-packages\modal\cls.py:556, in _Cls.from_name.<locals>._load_remote(obj, resolver, existing_object_id)
#     554 except GRPCError as exc:
#     555     if exc.status == Status.NOT_FOUND:
# --> 556         raise NotFoundError(exc.message)
#     557     elif exc.status == Status.FAILED_PRECONDITION:
#     558         raise InvalidError(exc.message)
#
# NotFoundError: Class not found in app
